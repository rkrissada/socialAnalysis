# %%
import random

a1=[1,2,3,4]
print(a1)

a2=['H','e','l','l','o',' ','W','o','r','l','d']
print(a2)

# การสร้าง list จากข้อความ 
a3=list('Hello World')
print(a3)

a4='I am a cat.'.split()
print(a4)

# List Comprehensions
a5=[x for x in range(5)]
print(a5)

a6=[random.randint(1,1000) for i in range(10)]
print(a6)
# Out:
# [1, 2, 3, 4]
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']
# ['I', 'am', 'a', 'cat.']
# [0, 1, 2, 3, 4]
# [771, 297, 191, 901, 804, 152, 242, 219, 408, 442]

# %%
for d in a6:
  print(d)
x = 15
if x in a6:
        print(x, 'อยู่ในลิสต์')
else:
        print(x,'ไม่อยู่ในลิสต์')
# Out:
# 771
# 297
# 191
# 901
# 804
# 152
# 242
# 219
# 408
# 442
# 15 ไม่อยู่ในลิสต์

# %%
from collections import Counter

data=[random.randint(1,20) for i in range(100)]
print(data)
counts=Counter(data)
counts.most_common()
# Out:
# [3, 19, 13, 10, 18, 15, 13, 4, 5, 8, 1, 2, 1, 10, 10, 5, 6, 20, 15, 15, 18, 5, 2, 4, 18, 10, 12, 14, 15, 16, 3, 1, 8, 18, 13, 1, 3, 15, 20, 2, 20, 9, 3, 12, 8, 4, 4, 8, 3, 10, 3, 6, 10, 5, 10, 1, 16, 9, 11, 19, 6, 3, 14, 17, 15, 13, 12, 20, 2, 12, 18, 18, 14, 1, 12, 18, 15, 14, 19, 17, 8, 17, 1, 17, 12, 17, 1, 8, 9, 9, 13, 2, 16, 4, 7, 4, 15, 18, 13, 10]
# [(10, 8),
#  (18, 8),
#  (15, 8),
#  (1, 8),
#  (3, 7),
#  (13, 6),
#  (4, 6),
#  (8, 6),
#  (12, 6),
#  (2, 5),
#  (17, 5),
#  (5, 4),
#  (20, 4),
#  (14, 4),
#  (9, 4),
#  (19, 3),
#  (6, 3),
#  (16, 3),
#  (11, 1),
#  (7, 1)]

# %%
from collections import Counter

f=open('CHULAMOOC_all_messages.txt',encoding='utf-8')
text=f.read()
tokens=text.split()
print(tokens)
counts=Counter(tokens)
print(counts.most_common())
f.close()
# Out:
# ['คอร์ส', 'สำหรับ', 'เดือน', 'พฤษภาคม', '2561', 'ขณะนี้', 'เปิด', 'ให้', 'ผู้', 'สนใจ', 'สามารถ', 'ลงทะเบียน', 'ได้', 'แล้ว', 'ค่ะ', '!', '+', 'ภาษา', 'รัสเซีย', 'เบื้องต้น', 'https://mooc.chula.ac.th/courses/cumooc-17', '+', 'ทำ', 'อย่างไร', 'ให้', 'สินค้า', 'Go', 'Inter', 'ขาย', 'ได้', 'ขายดี', 'และ', 'ดัง', 'ข้าม', 'โลก', 'รุ่น', 'ที่', '2', 'https://mooc.chula.ac.th/courses/cumooc-09', '+', 'Survival', 'Thai', 'รุ่น', 'ที่', '2', 'https://mooc.chula.ac.th/courses/cumooc-11', '+', 'Thai', 'on', 'Campus', 'รุ่น', 'ที', '2', 'https://mooc.chula.ac.th/courses/cumooc-12', '---', '(', 'หมายเหตุ', ':', 'หาก', 'ไม่', 'สามารถ', 'เปิด', 'Link', 'หน้า', 'ลงทะเบียน', 'ได้', 'เช่น', 'หน้าจอ', 'แสดง', 'เป็น', 'สี', 'ขาว', 'ค้าง', 'หรือ', 'แสดง', 'ข้อความ', 'เกี่ยวกับ', 'ความปลอดภัย', 'ขอให้', 'ลอง', 'เปลี่ยนไป', 'ใช้', 'Web', 'Browser', 'อื่น', 'ใน', 'การ', 'เปิด', 'Link', 'ดังกล่าว', 'แทน', 'เช่น', 'Chrome', '/', 'Safari', '/', 'Firefox', 'เป็นต้น', ')', 'อีก', 'หนึ่ง', 'คอร์ส', 'ที่', 'ได้รับ', 'ความสนใจ', 'เป็น', 'อย่างดี', "'", 'ทำ', 'อย่างไร', 'ให้', 'สินค้า', 'Go', 'Inter', '...', 'ขาย', 'ได้', 'ขายดี', 'และ', 'ดัง', 'ข้าม', 'โลก', "'", 'เปิด', 'รุ่น', 'ที่', '2', 'แล้ว', 'จ้า', 'าาาาา', 'แล้ว', 'พบกัน', 'พรุ่งนี้', 'เช้า', '[', '11', '/', '5', '/', '2561', ']', 'นะคะ', '💟', '---', 'ติดตาม', 'รายละเอียด', 'เพิ่มเติม', 'ได้ที่', 'https://mooc.chula.ac.th/courses', 'มา', 'แล้ว', 'จ้า', 'มา', 'แล้ว', 'วว', 'วว', '~', 'คอร์ส', 'ที่จะ', 'เปิด', 'ให้', 'ลงทะเบียน', 'ใน', 'เดือน', 'นี้', 'วิชา', 'แรก', 'มา', 'แล้ว', 'จ้า', '..', 'วันพรุ่งนี้', 'เช้า', '[', '11', '/', '5', '/', '2018', ']', 'เตรียมตัว', 'ให้', 'พร้อม', '!', 'พบกัน', 'แน่นอน', 'จ้า', '---', 'ติดตาม', 'รายละเอียด', 'เพิ่มเติม', 'ได้ที่', 'https://mooc.chula.ac.th/courses', 'สำหรับ', 'ช่วง', 'วันหยุด', 'ยาว', 'ใน', 'เทศกาล', 'สงกรานต์', 'นี้', 'ทาง', 'โครงการ', 'CHULA', 'MOOC', 'จะ', 'ทำการ', "'", 'ปิด', 'ปรับปรุง', 'ระบบ', "'", 'ใน', 'ช่วงเวลา', '22.00', 'น.', 'ของ', 'คืน', 'วันที่', '14', 'เม.ย.', '61', 'ถึง', 'เวลา', '06.00', 'น.', 'ของ', 'เช้า', 'วันที่', '15', 'เม.ย.', '61', 'โดย', 'ระหว่าง', 'เวลา', 'ดังกล่าว', 'จะ', 'ไม่', 'สามารถ', 'เข้า', 'ใช้งาน', 'ระบบ', 'ได้', 'ขออภัย', 'ใน', 'ความไม่สะดวก', 'ด้วย', 'นะคะ', '🙏', 'คอร์ส', 'สำหรับ', 'เดือน', 'เมษายน', '2561', 'ขณะนี้', 'เปิด', 'ให้', 'ผู้', 'สนใจ', 'สามารถ', 'ลงทะเบียน', 'ได้', 'แล้ว', 'ค่ะ', '!', 'ลงทะเบียน', 'ได้ที่', '..', '+', 'การ', 'สร้าง', 'Infographics', ':', 'What', '&', 'How', '?', 'รุ่น', 'ที่', '2', 'https://mooc.chula.ac.th/courses/cumooc-08', '***', 'ขณะนี้', 'มี', 'ผู้', 'ลงทะเบียน', 'เต็ม', 'แล้ว', '***', '+', 'หลักการ', 'พื้นฐาน', 'ทาง', 'กฎหมายอาญา', 'https://mooc.chula.ac.th/courses/cumooc-16', 'รีบ', 'ๆ', 'ลงทะเบียน', 'กัน', 'เข้ามา', 'นะคะ', '💟', 'คอร์ส', 'ประจำเดือน', 'เมษายน', '2561', 'กำลังจะ', 'เปิด', 'ให้', 'ผู้', 'สนใจ', 'ลงทะเบียน', 'แล้ว', 'จ้า', '!', '✔️', 'การ', 'สร้าง', 'Infographics', ':', 'What', '&', 'How', '?', 'รุ่น', 'ที่', '2', '***', 'ขณะนี้', 'มี', 'ผู้', 'ลงทะเบียน', 'เต็ม', 'แล้ว', '***', '✔️', 'หลักการ', 'พื้นฐาน', 'ทาง', 'กฎหมายอาญา', 'แล้ว', 'พบกัน', 'วันพรุ่งนี้', 'ช่วง', 'เช้า', '[', '11', '/', '04', '/', '2561', ']', 'นะคะ', ':)', '---', 'ลงทะเบียน', 'ได้ที่', 'https://mooc.chula.ac.th/courses', 'ใคร', 'ที่', 'กำลัง', 'รอ', 'ว่า', 'คอร์ส', 'ต่อไป', 'ที่จะ', 'เปิด', 'ให้', 'ลงทะเบียน', 'ใน', 'เดือน', 'นี้', 'คือ', 'อะไร', '?', '..', 'มา', 'แล้ว', 'นะ', 'จ๊าาาาา', "'", 'หลักการ', 'พื้นฐาน', 'ทาง', 'กฎหมายอาญา', "'", 'เป็น', 'อีก', 'หนึ่ง', 'คอร์ส', 'ที่จะ', 'เปิด', 'ให้', 'ลงทะเบียน', 'ใน', 'เดือน', 'นี้', 'ค่ะ', 'แล้ว', 'พบกัน', 'เร็ว', 'ๆ', 'นี้', 'แน่นอน', 'ปัก', 'หมุด', 'รอ', 'ไว้', 'ได้', 'เลย', '!', '-----', 'รายละเอียด', 'เพิ่มเติม', 'https://mooc.chula.ac.th/courses', '++', 'ขณะนี้', 'มี', 'ผู้', 'ลงทะเบียน', 'เต็ม', 'จำนวน', 'แล้ว', '++', '.', '.', 'ขอ', 'ต้อนรับ', 'เดือน', 'เมษายน', 'ที่', 'ร้อนแรง', 'ด้วย', 'คอร์ส', 'ที่', 'Hot', 'ไม่', 'แพ้', 'กัน', '!', 'กับ', 'คอร์ส', "'", 'การ', 'สร้าง', 'Infographics', ':', 'What', '&', 'How', "?'", 'รุ่น', 'ที่', '2',  ...
# [('ที่', 153), ('ได้', 129), (':', 125), ('ท่าน', 120), ('แล้ว', 116), ("'", 116), ('ลงทะเบียน', 95), ('สามารถ', 92), ('ใน', 90), ('จะ', 83), ('วิชา', 82), ('/', 78), ('ให้', 76), ('ผู้', 75), ('Certificate', 75), ('เปิด', 73), ('แบบ', 73), ('สำรวจ', 69), ('การ', 65), ('Link', 57), ('ขอรับ', 57), ('.', 56), ('มี', 54), ('ผู้เรียน', 51), ('หาก', 48), ('สำหรับ', 43), (')', 43), ('ๆ', 43), ('ทำ', 42), ('และ', 41), ('(', 41), ('คอร์ส', 40), ('หมายเหตุ', 39), ('ไม่', 38), ('of', 38), ('Completion', 38), ('ตอบ', 37), ('หน้า', 36), ('นี้', 36), ('ของ', 35), ('ได้ที่', 34), ('CHULA', 33), ('MOOC', 33), ('2', 32), ('รายชื่อ', 32), ('มา', 31), ('มีสิทธิ์', 30), ('Learner', 30), ('ID', 30), ('ขณะนี้', 29), ('เช่น', 29), ('ขอให้', 28), ('กัน', 28), ('อยู่', 28), ('!', 27), ('เพิ่มเติม', 27), ('1.', 27), ('2.', 27), ('e-mail', 27), ('ค่ะ', 26), ('for', 26), ('อื่น', 25), ('นะคะ', 25), ('..', 25), ('รายวิชา', 25), ('เข้าสู่', 24), ('ไว้', 23), ('กับ', 23), ('ปุ่ม', 23), ('ดังกล่าว', 22), ('เต็ม', 22), ('พบกัน', 21), ('เรียบร้อย', 21), ('ตรวจสอบ', 21), ('ทุก', 21), ('Web', 20), ('Browser', 20), ('แทน', 20), ('Chrome', 20), ('Safari', 20), ('Firefox', 20), ('เป็นต้น', 20), ('++', 20), ('เลือก', 20), ('เมนู', 20), ('Account', 20), ('รุ่น', 19), ('แสดง', 19), ('เป็น', 19), ('https://mooc.chula.ac.th/courses', 19), ('ทาง', 19), ('เพื่อ', 19), ('ข้อมูล', 19), ('-----------', 19), ('ใช้', 18), ('รายละเอียด', 18), ('เร็ว', 18), ('เรียน', 18), ('ค่า', 18), ('เดือน', 17), ('จำนวน', 17), ('Log', 17), ('in', 17), ('3.', 17), ('4.', 17), (',', 17), ('วิธีการ', 16), ('ครบ', 16), ('2561', 15), ('สนใจ', 15), ('โดย', 15), ('เลย', 15), ('ไป', 15), ('+', 14), ('ภาษา', 14), ('ติดตาม', 14), ('พบ', 14), ('จัดส่ง', 14), ('Data', 14), ('and', 14), ('Facebook', 14), ('ข้อ', 14), ('วันที่', 13), ('รอ', 13), ('คุณ', 13), ('ตาม', 13), ('ปรากฎ', 13), ('chula', 13), ('ac', 13), ('th', 13), ('●', 13), ('น้า', 12), ('Course', 12), ('ใหม่', 12), ('การตลาด', 12), ('Page', 12), ('เมื่อ', 12), ('อาหรับ', 12), ('English', 12), ('Careers', 12), ('หรือ', 11), ('เกี่ยวกับ', 11), ('เปลี่ยนไป', 11), ('จ้า', 11), ('เวลา', 11), ('?', 11), ('รีบ', 11), ('ใคร', 11), ('คือ', 11), ('ดู', 11), ('รับ', 11), ('แล้', 11), ('วจะ', 11), ('ทยอย', 11), ('ข้อสงสัย', 11), ('chulamooc', 11), ('@', 11), ('-', 11), ('จาก', 11), ('ขั้นตอน', 11), ('ลงทะเบียนเรียน', 11), ('ใกล้', 11), ('งบการเงิน', 11), ('For', 11), ('ใด', 11), ('อย่างไร', 10), ('Thai', 10), ('---', 10), ('อีก', 10), ('ที่จะ', 10), ('ระบบ', 10), ('น.', 10), ('&', 10), ('How', 10), ('วัน', 10), ('ประกาศ', 10), ('เรา', 10), ('ช่องทาง', 10), ('รูปภาพ', 10), ('อัลบั้ม', 10), ('ค้นหา', 10), ('My', 10), ('ซึ่ง', 10), ('มุม', 10), ('บนสุด', 10), ('ด้าน', 10), ('ขวามือ', 10), ('Info', 10), ('ต้องการ', 10), ('นำ', 10), ('หลังจากที่', 10), ('ติดต่อสอบถาม', 10), ('เพียง', 10), ('ทำความเข้าใจ', 10), ('หน้าจอ', 9), ('สี', 9), ('ขาว', 9), ('ค้าง', 9), ('ข้อความ', 9), ('ความปลอดภัย', 9), ('ลอง', 9), ('ได้รับ', 9), ('สร้าง', 9), ('Infographics', 9), ('What', 9), ('ว่า', 9), ('Critical', 9), ('Thinking', 9), ('Business', 9), ('เข้าไป', 9), ('Progress', 9), ('ทั้งนี้', 9), ('ศตวรรษ', 9), ('21', 9), ('2560', 9), ('Go', 8), ('Inter', 8), ('✔️', 8), (':)', 8), ('ขอ', 8), ('ทำให้', 8), ('นั้น', 8), ('to', 8), ('อีกครั้ง', 8), ('การเรียน', 8), ('(https://mooc.chula.ac.th/courses)', 8), ('ทำได้', 8), ('สินค้า', 7), ('ขาย', 7), ('ขายดี', 7), ('โลก', 7), ('เตรียมตัว', 7), ('ด้วย', 7), ('หลักการ', 7), ('พื้นฐาน', 7), ('09.00', 7), ('IT', 7), ('Intro', 7), ('Analytics', 7), ('Big', 7), ('สิ้นสุด', 7), ('2,000', 7), ('คน', 7), ('เท่านั้น', 7), ('-----------------------', 7), ('ดังนี้', 7), ('เห็น', 7), ('ด้านล่าง', 7), ('ชื่อ', 7), ('เปอร์เซ็นต์', 7), ('คลิก', 7), ('Follow', 7), ('5.', 7), ('หมด', 7), ('กด', 7), ('ส่ง', 7), ('Submit', 7), ('6.', 7), ('ที่อยู่', 7), ('ระบุ', 7), ('ครั้ง', 7), ('เดียว', 7), ('ทำซ้ำ', 7), ('เคย', 7), ('รบกวน', 7), ('Staff', 7), ('https://mooc.chula.ac.th', 7), ('เปลี่ยน', 7), ('Survival', 6), ('เช้า', 6), ('วันพรุ่งนี้', 6), ('***', 6 ...

# %%
b1=('Python for Data Science',178)
b2=('Introduction to Python',160)
b3=('วิทยาการคำนวณ',35)
b4=('ภาษาโปรแกรม',200)

books = [b1,b2,b3,b4]
print(books)
print(sorted(books))
print(books)
new_books = [(p,b) for (b,p) in books]
print(new_books)
print(sorted(new_books,reverse=True))

price=[p for (p,b) in new_books]
print(price)
print(sum(price)/len(price))
# Out:
# [('Python for Data Science', 178), ('Introduction to Python', 160), ('วิทยาการคำนวณ', 35), ('ภาษาโปรแกรม', 200)]
# [('Introduction to Python', 160), ('Python for Data Science', 178), ('ภาษาโปรแกรม', 200), ('วิทยาการคำนวณ', 35)]
# [('Python for Data Science', 178), ('Introduction to Python', 160), ('วิทยาการคำนวณ', 35), ('ภาษาโปรแกรม', 200)]
# [(178, 'Python for Data Science'), (160, 'Introduction to Python'), (35, 'วิทยาการคำนวณ'), (200, 'ภาษาโปรแกรม')]
# [(200, 'ภาษาโปรแกรม'), (178, 'Python for Data Science'), (160, 'Introduction to Python'), (35, 'วิทยาการคำนวณ')]
# [178, 160, 35, 200]
# 143.25

# %%
f=open('ข้อมูลการจดทะเบียนนิติบุคคล_พ.ศ._2558_รายชื่อนิติบุคคลจัดตั้งใหม่_เดือนมกราคม_CSV.csv',encoding='cp874')
lines=f.readlines()[4:]
f.close()
data=dict()
for line in lines:
  tokens=line.split(',')
  data[tokens[1]] = tokens[2]

print(data['0105558002009'])
# Out:
# บจ.โจงลี่ เทลซัน โซล่าร์ (ไทยแลนด์) จำกัด

# %%
f=open('ข้อมูลการจดทะเบียนนิติบุคคล_พ.ศ._2558_รายชื่อนิติบุคคลจัดตั้งใหม่_เดือนมกราคม_CSV.csv',encoding='cp874')
lines=f.readlines()[4:]
f.close()
data=list()
for line in lines:
  tokens=line.split(',')
  data.append({'id':tokens[1],'registered name':tokens[2],'registered date':tokens[3]})

print(data[10]['registered name'],data[10]['registered date'])
# Out:
# บจ.เทคโทรนิค อินดัสตรี้ส์ (ประเทศไทย) จำกัด 12/1/2558

# %%
f=open('CHULAMOOC_all_messages.txt',encoding='utf-8')
text=f.read()
f.close()
tokens=text.split()
print(tokens)
print(set(tokens))
# Out:
# ['คอร์ส', 'สำหรับ', 'เดือน', 'พฤษภาคม', '2561', 'ขณะนี้', 'เปิด', 'ให้', 'ผู้', 'สนใจ', 'สามารถ', 'ลงทะเบียน', 'ได้', 'แล้ว', 'ค่ะ', '!', '+', 'ภาษา', 'รัสเซีย', 'เบื้องต้น', 'https://mooc.chula.ac.th/courses/cumooc-17', '+', 'ทำ', 'อย่างไร', 'ให้', 'สินค้า', 'Go', 'Inter', 'ขาย', 'ได้', 'ขายดี', 'และ', 'ดัง', 'ข้าม', 'โลก', 'รุ่น', 'ที่', '2', 'https://mooc.chula.ac.th/courses/cumooc-09', '+', 'Survival', 'Thai', 'รุ่น', 'ที่', '2', 'https://mooc.chula.ac.th/courses/cumooc-11', '+', 'Thai', 'on', 'Campus', 'รุ่น', 'ที', '2', 'https://mooc.chula.ac.th/courses/cumooc-12', '---', '(', 'หมายเหตุ', ':', 'หาก', 'ไม่', 'สามารถ', 'เปิด', 'Link', 'หน้า', 'ลงทะเบียน', 'ได้', 'เช่น', 'หน้าจอ', 'แสดง', 'เป็น', 'สี', 'ขาว', 'ค้าง', 'หรือ', 'แสดง', 'ข้อความ', 'เกี่ยวกับ', 'ความปลอดภัย', 'ขอให้', 'ลอง', 'เปลี่ยนไป', 'ใช้', 'Web', 'Browser', 'อื่น', 'ใน', 'การ', 'เปิด', 'Link', 'ดังกล่าว', 'แทน', 'เช่น', 'Chrome', '/', 'Safari', '/', 'Firefox', 'เป็นต้น', ')', 'อีก', 'หนึ่ง', 'คอร์ส', 'ที่', 'ได้รับ', 'ความสนใจ', 'เป็น', 'อย่างดี', "'", 'ทำ', 'อย่างไร', 'ให้', 'สินค้า', 'Go', 'Inter', '...', 'ขาย', 'ได้', 'ขายดี', 'และ', 'ดัง', 'ข้าม', 'โลก', "'", 'เปิด', 'รุ่น', 'ที่', '2', 'แล้ว', 'จ้า', 'าาาาา', 'แล้ว', 'พบกัน', 'พรุ่งนี้', 'เช้า', '[', '11', '/', '5', '/', '2561', ']', 'นะคะ', '💟', '---', 'ติดตาม', 'รายละเอียด', 'เพิ่มเติม', 'ได้ที่', 'https://mooc.chula.ac.th/courses', 'มา', 'แล้ว', 'จ้า', 'มา', 'แล้ว', 'วว', 'วว', '~', 'คอร์ส', 
'จ๊าาาาา', "'", 'หลักการ', 'พื้นฐาน', 'ทาง', 'กฎหมายอาญา', "'", 'เป็น', 'อีก', 'หนึ่ง', 'คอร์ส', 'ที่จะ', 'เปิด', 'ให้', 'ลงทะเบียน', 'ใน', 'เดือน', 'นี้', 'ค่ะ', 'แล้ว', 'พบกัน', 'เร็ว', 'ๆ', 'นี้', 'แน่นอน', 'ปัก', 'หมุด', 'รอ', 'ไว้', 'ได้', 'เลย', '!', '-----', 'รายละเอียด', 'เพิ่มเติม', 'https://mooc.chula.ac.th/courses', '++', 'ขณะนี้', 'มี', 'ผู้', 'ลงทะเบียน', 'เต็ม', 'จำนวน', 'แล้ว', '++', '.', '.', 'ขอ', 'ต้อนรับ', 'เดือน', 'เมษายน', 'ที่', 'ร้อนแรง', 'ด้วย', 'คอร์ส', 'ที่', 'Hot', 'ไม่', 'แพ้', 'กัน', '!', 'กับ', 'คอร์ส', "'", 'การ', 'สร้าง', 'Infographics', ':', 'What', '&', 'How', "?'", 'รุ่น', 'ที่', '2',  ...
# {'https://mooc.chula.ac.th/courses/arabicfordailylife', '---------------------------', 'ทำความเข้าใจ', 'ต่างๆ', '09.00', 'ประกาศ', 'Chrome', 'Completion', 'https://mooc.chula.ac.th/wp-content/uploads/2017/12/รายชื่อผู้มีสิทธิ์ขอรับ-Certificate-วิชา-English-for-Careers-II-For-Restaurant-staff-.pdf', 'อย่า', 'มีสิทธิ์', 'มา', 'ไม่', ':)', 'หา', 'อยู่', 'แห่ง', 'ทำการ', 'I', 'มุมมอง', 'ท่า', 'โครงการ', 'farewell', 'ภาษาจีน', 'sign', 'https://mooc.chula.ac.th/wp-content/uploads/2017/11/รายชื่อผู้มีสิทธิ์ขอรับ-Certificate-วิชาภาษาอาหรับในชีวิตประจำวัน-.pdf', 'นักท่องเที่ยว', 'thank', 'ly', 'มีนาคม', 'ต้องการ', 'of', 'รับ', 'เรา', 'เทคนิค', 'Library', '12', '"', '14.30', 'คำศัพท์', 'มากกว่า', 'ดีกว่า', 'ศุกร์', 'https://mooc.chula.ac.th/courses/cumooc-14', 'Infographics', 'Go', 'สำหรับ', 'รอบ', 'Link', '!!..', '-------------------', 'ชีวิต', 'ตุลาคม', 'making', 'นะ', 'an', 'ทักษะ', 'time', 'Website', 'รุ่น', 'การสื่อสาร', 'https://mooc.chula.ac.th/wp-content/uploads/2018/02/รายชื่อผู้มีสิทธิ์ขอรับ-Certificate-วิชา-IT-Security.pdf', 'กฎหมายอาญา', 'แค่', '06.00', 'Intro', '++', 'Open', 'ตอบ', 'know', 'คืน', '🙏💗', 'ภาษาอังกฤษ', 'https://mooc.chula.ac.th/wp-content/uploads/2018/01/รายชื่อผู้มีสิทธิ์ขอรับ-Certificate-วิชา-Infographic-.pdf', 'ดังนี้', 'เริ่ม', 'พวกเรา', 'กัน', 'ขั้นตอน', 'Graphic', 'ยัง', 'you', '[', 'ขายดี', 'การ', 'ทันที', 'Group', 'ไร้พรมแดน', "'", 'การตลาด', '❤️🌹❤️', 'าา', 'เมื่อ', 'ผลงาน', 'https://mooc.chula.ac.th/courses
ข่าวดี', '------------------------------------------', 'https://mooc.chula.ac.th/wp-content/uploads/2017/11/รายชื่อผู้มีสิทธิ์ขอรับ-Certificate-วิชาการทำความเข้าใจงบการเงิน-.pdf', 'self-introduction', 'https://mooc.chula.ac.th/courses/marketingin21stcentury', 'ID', 'ศตวรรษ', '(https://mooc.chula.ac.th/step-certificate)', 'อาหรับ', 'hobbies', 'พัฒนา', '1.', '3', 'สื่อสาร', 'date', 'เดียว', 'ชื่อ', 'ออกเสียง', '28', 'พรุ่งนี้', 'แก้ไข', 'courses', 'เพิ่ม', 'directions', 'ปีหน้า', 'Inter', 'FB', 'เคย', 'กำลังจะ', 'รบกวน', 'อย่างไร', '20', '15', 'campus', '#', '80', '🗞️👨\u200d🎓', 'ระห ...

# %%
f1=open('CHULAMOOC_all_messages.txt',encoding='utf-8')
f2=open('ChulaEngineering_all_messages.txt',encoding='utf-8')
text=f1.read()
tokens1=set(text.split())
text=f2.read()
tokens2=set(text.split())
f1.close()
f2.close()

print(tokens1.intersection(tokens2))
# Out:
# {'09.00', 'ประกาศ', 'อย่า', 'มา', 'ไม่', 'อยู่', 'แห่ง', 'ทำการ', 'I', 'มุมมอง', 'โครงการ', 'of', 'มีนาคม', 'ต้องการ', 'รับ', 'เรา', '12', '"', '14.30', 'ศุกร์', 'รอบ', 'สำหรับ', 'Link', 'ตุลาคม', 'making', 'นะ', 'an', 'ทักษะ', 'รุ่น', 'การสื่อสาร', 'Open', 'ตอบ', 'ดังนี้', 'เริ่ม', 'กัน', 'ขั้นตอน', 'ยัง', 'you', 'การ', "'", 'การตลาด', 'เมื่อ', 'ผลงาน', 'น', 'course', '/', 'ฟรี', 'เวลา', 'ๆ', 'ได้ที่', 'วันที่', 'ไกล', 'สำคัญ', 'อีก', 'ที่จะ', 'the', 'ความปลอดภัย', 'การเรียน', '1', 'สอบถาม', 'เม.ย.', 'ac', 'ยาว', 'วิวัฒนาการ', 'บรรยากาศ', 'รัสเซีย', 'กุมภาพันธ์', '2018', 'เพียง', '.', 'รู้', 'e-mail', 'โลก', 'For', 'English', 'ค้นหา', 'เป็น', 'ทุกท่าน', 'กำหนด', '60', 'มกราคม', ':', 'เข้าสู่', 'ธุรกิจ', 'อย่างดี', 'พร้อม', 'รายวิชา', 'ใช้', 'ส่ง', 'เข้าร่วม', 'เปิด', 'สามารถ', '30', 'สร้าง', 'ตรวจสอบ', 'วิชาการ', 'ใคร', 'อันดับ', 'อย่าง', 'เกี่ยวกับ', 'body', 'คือ', 'ปิด', 'กิจกรรม', 'คน', 'ภาษา', 'Big', 'ครบรอบ', 'จาก', 'แต่ละ', 'ช่วง', 'แจ้ง', 'is', 'ทำให้', 'เป็นต้นไป', 'เช้า', 'สมัคร', ',', 'Info', 'Thinking', 'กระบวน', '2.', 'and', 'เพื่อ', 'ทั้ง', 'ได้แก่', 'ถึง', 'การตอบรับ', '2560', 'ติดตาม', 'ปรับปรุง', 'ศตวรรษ', 'พัฒนา', '1.', '3', 'สื่อสาร', 'date', 'ชื่อ', '28', 'courses', 'เพิ่ม', 'เคย', 'กำลังจะ',